# %% [markdown]
# <a href="https://colab.research.google.com/github/MichaelOkoro24/Neural_Network_Charity_Analysis/blob/main/AlphabetSoupCharity_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# Import and read charity_data.csv
import pandas as pd 
application_df = pd.read_csv('/charity_data.csv')
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
###  Preprocess the data

# %%
# Drop non-beneficial ID columns
application_df = application_df.drop(columns=['EIN', 'NAME', 'STATUS', 'SPECIAL_CONSIDERATIONS'])

# %%
# APPLICATION_TYPE value counts for binning
application_values = application_df['APPLICATION_TYPE'].value_counts()

# Determine which values to replace if counts are less than 1000
replace_application = application_values[application_values < 1000].index.tolist()

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app, 'Other')

# %%
# CLASSIFICATION value counts for binning
classification_values = application_df['CLASSIFICATION'].value_counts()

# Determine which values to replace if counts are less than 1000
replace_class = classification_values[classification_values < 1000].index.tolist()

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls, 'Other')

# %%
# ASK_AMT bins
ask_values_0 = application_df['ASK_AMT'][application_df['ASK_AMT'] == 5000]
ask_values_1 = application_df['ASK_AMT'][(application_df['ASK_AMT'] > 5000)]

# Replace in dataframe
for amt in ask_values_0:
    application_df.ASK_AMT = application_df.ASK_AMT.replace(amt, '5000')
for amt in ask_values_1:
    application_df.ASK_AMT = application_df.ASK_AMT.replace(amt, '>5000')

# %%
# AFFILIATION value counts for binning
affiliation_values = application_df['AFFILIATION'].value_counts()

# Determine which values to replace if counts are less than 1000
replace_affiliation = affiliation_values[affiliation_values < 1000].index.tolist()

# Replace in dataframe
for aff in replace_affiliation:
    application_df.AFFILIATION = application_df.AFFILIATION.replace(aff, 'Other')

# %%
# ORGANIZATION value counts for binning
organization_values = application_df['ORGANIZATION'].value_counts()

# Determine which values to replace if counts are less than 1000
replace_organization = organization_values[organization_values < 1000].index.tolist()

# Replace in dataframe
for org in replace_organization:
    application_df.ORGANIZATION = application_df.ORGANIZATION.replace(org, 'Other')

# %%
# Generate the categorical variable list
application_cat = application_df.dtypes[application_df.dtypes == "object"].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(application_cat)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(application_cat, 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Split the preprocessed data into features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(['IS_SUCCESSFUL'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
## Design a neural network model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 120
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 18

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="sigmoid"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hiZdden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 120)               4200
#
#  dense_1 (Dense)             (None, 50)                6050
#
#  dense_2 (Dense)             (None, 18)                918
#
#  dense_3 (Dense)             (None, 1)                 19
#
# =================================================================
# Total params: 11,187
# Trainable params: 11,187
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
### Create a callback

# %%
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs('optimized_checkpoints/', exist_ok=True)
checkpoint_path = 'optimized_checkpoints/weights.{epoch:02d}.hdf5'

# Create a callback that saves the model's weights every 5 epochs
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq=4000)

# %%
# Train the model
fit_model = nn.fit(X_train, y_train, epochs=200, callbacks=[cp_callback])
# Out:
# Epoch 1/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6050 - accuracy: 0.6930
# Epoch 2/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5786 - accuracy: 0.7174
# Epoch 3/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5716 - accuracy: 0.7219
# Epoch 4/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5689 - accuracy: 0.7226
# Epoch 5/200
# 764/804 [===========================>..] - ETA: 0s - loss: 0.5661 - accuracy: 0.7253
# Epoch 5: saving model to optimized_checkpoints/weights.05.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5661 - accuracy: 0.7252
# Epoch 6/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5644 - accuracy: 0.7293
# Epoch 7/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5630 - accuracy: 0.7288
# Epoch 8/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5603 - accuracy: 0.7285
# Epoch 9/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5603 - accuracy: 0.7304
# Epoch 10/200
# 759/804 [===========================>..] - ETA: 0s - loss: 0.5577 - accuracy: 0.7316
# Epoch 10: saving model to optimized_checkpoints/weights.10.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5590 - accuracy: 0.7305
# Epoch 11/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5588 - accuracy: 0.7311
# Epoch 12/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5574 - accuracy: 0.7301
# Epoch 13/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5571 - accuracy: 0.7313
# Epoch 14/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5562 - accuracy: 0.7323
# Epoch 15/200
# 738/804 [==========================>...] - ETA: 0s - loss: 0.5565 - accuracy: 0.7305
# Epoch 15: saving model to optimized_checkpoints/weights.15.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5560 - accuracy: 0.7315
# Epoch 16/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5555 - accuracy: 0.7306
# Epoch 17/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5547 - accuracy: 0.7321
# Epoch 18/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5538 - accuracy: 0.7329
# Epoch 19/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5540 - accuracy: 0.7307
# Epoch 20/200
# 713/804 [=========================>....] - ETA: 0s - loss: 0.5518 - accuracy: 0.7330
# Epoch 20: saving model to optimized_checkpoints/weights.20.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5533 - accuracy: 0.7318
# Epoch 21/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5527 - accuracy: 0.7319
# Epoch 22/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5533 - accuracy: 0.7329
# Epoch 23/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5524 - accuracy: 0.7320
# Epoch 24/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5522 - accuracy: 0.7332
# Epoch 25/200
# 687/804 [========================>.....] - ETA: 0s - loss: 0.5539 - accuracy: 0.7314
# Epoch 25: saving model to optimized_checkpoints/weights.25.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5519 - accuracy: 0.7328
# Epoch 26/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7329
# Epoch 27/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5513 - accuracy: 0.7317
# Epoch 28/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7330
# Epoch 29/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5507 - accuracy: 0.7334
# Epoch 30/200
# 669/804 [=======================>......] - ETA: 0s - loss: 0.5514 - accuracy: 0.7329
# Epoch 30: saving model to optimized_checkpoints/weights.30.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5508 - accuracy: 0.7329
# Epoch 31/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5508 - accuracy: 0.7331
# Epoch 32/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5506 - accuracy: 0.7333
# Epoch 33/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5504 - accuracy: 0.7331
# Epoch 34/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5497 - accuracy: 0.7335
# Epoch 35/200
# 660/804 [=======================>......] - ETA: 0s - loss: 0.5487 - accuracy: 0.7353
# Epoch 35: saving model to optimized_checkpoints/weights.35.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5498 - accuracy: 0.7343
# Epoch 36/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5495 - accuracy: 0.7333
# Epoch 37/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7339
# Epoch 38/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5491 - accuracy: 0.7332
# Epoch 39/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5493 - accuracy: 0.7342
# Epoch 40/200
# 625/804 [======================>.......] - ETA: 0s - loss: 0.5476 - accuracy: 0.7360
# Epoch 40: saving model to optimized_checkpoints/weights.40.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5489 - accuracy: 0.7347
# Epoch 41/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5488 - accuracy: 0.7346
# Epoch 42/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5488 - accuracy: 0.7332
# Epoch 43/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5484 - accuracy: 0.7355
# Epoch 44/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5483 - accuracy: 0.7347
# Epoch 45/200
# 622/804 [======================>.......] - ETA: 0s - loss: 0.5494 - accuracy: 0.7325
# Epoch 45: saving model to optimized_checkpoints/weights.45.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5482 - accuracy: 0.7345
# Epoch 46/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7345
# Epoch 47/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5481 - accuracy: 0.7351
# Epoch 48/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5474 - accuracy: 0.7359
# Epoch 49/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5477 - accuracy: 0.7347
# Epoch 50/200
# 588/804 [====================>.........] - ETA: 0s - loss: 0.5476 - accuracy: 0.7343
# Epoch 50: saving model to optimized_checkpoints/weights.50.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5474 - accuracy: 0.7351
# Epoch 51/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5476 - accuracy: 0.7347
# Epoch 52/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5471 - accuracy: 0.7353
# Epoch 53/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5473 - accuracy: 0.7350
# Epoch 54/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7361
# Epoch 55/200
# 565/804 [====================>.........] - ETA: 0s - loss: 0.5470 - accuracy: 0.7322
# Epoch 55: saving model to optimized_checkpoints/weights.55.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7348
# Epoch 56/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7353
# Epoch 57/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7358
# Epoch 58/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7347
# Epoch 59/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5466 - accuracy: 0.7350
# Epoch 60/200
# 562/804 [===================>..........] - ETA: 0s - loss: 0.5477 - accuracy: 0.7354
# Epoch 60: saving model to optimized_checkpoints/weights.60.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5462 - accuracy: 0.7367
# Epoch 61/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7363
# Epoch 62/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5461 - accuracy: 0.7352
# Epoch 63/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5461 - accuracy: 0.7360
# Epoch 64/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5460 - accuracy: 0.7360
# Epoch 65/200
# 536/804 [===================>..........] - ETA: 0s - loss: 0.5450 - accuracy: 0.7364
# Epoch 65: saving model to optimized_checkpoints/weights.65.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7360
# Epoch 66/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7357
# Epoch 67/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7358
# Epoch 68/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5458 - accuracy: 0.7370
# Epoch 69/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5452 - accuracy: 0.7357
# Epoch 70/200
# 510/804 [==================>...........] - ETA: 0s - loss: 0.5435 - accuracy: 0.7365
# Epoch 70: saving model to optimized_checkpoints/weights.70.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5454 - accuracy: 0.7361
# Epoch 71/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5454 - accuracy: 0.7368
# Epoch 72/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5452 - accuracy: 0.7362
# Epoch 73/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7365
# Epoch 74/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7364
# Epoch 75/200
# 497/804 [=================>............] - ETA: 0s - loss: 0.5447 - accuracy: 0.7360
# Epoch 75: saving model to optimized_checkpoints/weights.75.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5450 - accuracy: 0.7364
# Epoch 76/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5450 - accuracy: 0.7367
# Epoch 77/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5448 - accuracy: 0.7364
# Epoch 78/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5447 - accuracy: 0.7362
# Epoch 79/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5447 - accuracy: 0.7360
# Epoch 80/200
# 476/804 [================>.............] - ETA: 0s - loss: 0.5416 - accuracy: 0.7404
# Epoch 80: saving model to optimized_checkpoints/weights.80.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7368
# Epoch 81/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5445 - accuracy: 0.7364
# Epoch 82/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5445 - accuracy: 0.7364
# Epoch 83/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5441 - accuracy: 0.7369
# Epoch 84/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7364
# Epoch 85/200
# 452/804 [===============>..............] - ETA: 0s - loss: 0.5435 - accuracy: 0.7371
# Epoch 85: saving model to optimized_checkpoints/weights.85.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5444 - accuracy: 0.7372
# Epoch 86/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.7366
# Epoch 87/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5438 - accuracy: 0.7369
# Epoch 88/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5439 - accuracy: 0.7370
# Epoch 89/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5437 - accuracy: 0.7376
# Epoch 90/200
# 435/804 [===============>..............] - ETA: 0s - loss: 0.5368 - accuracy: 0.7424
# Epoch 90: saving model to optimized_checkpoints/weights.90.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5436 - accuracy: 0.7373
# Epoch 91/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5434 - accuracy: 0.7368
# Epoch 92/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7369
# Epoch 93/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5432 - accuracy: 0.7371
# Epoch 94/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5433 - accuracy: 0.7378
# Epoch 95/200
# 412/804 [==============>...............] - ETA: 1s - loss: 0.5408 - accuracy: 0.7379
# Epoch 95: saving model to optimized_checkpoints/weights.95.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5429 - accuracy: 0.7373
# Epoch 96/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5430 - accuracy: 0.7379
# Epoch 97/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5432 - accuracy: 0.7365
# Epoch 98/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5431 - accuracy: 0.7376
# Epoch 99/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5429 - accuracy: 0.7372
# Epoch 100/200
# 396/804 [=============>................] - ETA: 1s - loss: 0.5441 - accuracy: 0.7361
# Epoch 100: saving model to optimized_checkpoints/weights.100.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5429 - accuracy: 0.7382
# Epoch 101/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5427 - accuracy: 0.7374
# Epoch 102/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5425 - accuracy: 0.7372
# Epoch 103/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5425 - accuracy: 0.7374
# Epoch 104/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5421 - accuracy: 0.7379
# Epoch 105/200
# 372/804 [============>.................] - ETA: 1s - loss: 0.5435 - accuracy: 0.7386
# Epoch 105: saving model to optimized_checkpoints/weights.105.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5421 - accuracy: 0.7385
# Epoch 106/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5419 - accuracy: 0.7382
# Epoch 107/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5421 - accuracy: 0.7374
# Epoch 108/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5417 - accuracy: 0.7382
# Epoch 109/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5419 - accuracy: 0.7373
# Epoch 110/200
# 343/804 [===========>..................] - ETA: 1s - loss: 0.5330 - accuracy: 0.7482
# Epoch 110: saving model to optimized_checkpoints/weights.110.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5416 - accuracy: 0.7374
# Epoch 111/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7375
# Epoch 112/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5416 - accuracy: 0.7388
# Epoch 113/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7384
# Epoch 114/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5416 - accuracy: 0.7382
# Epoch 115/200
# 339/804 [===========>..................] - ETA: 1s - loss: 0.5444 - accuracy: 0.7329
# Epoch 115: saving model to optimized_checkpoints/weights.115.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5414 - accuracy: 0.7384
# Epoch 116/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5413 - accuracy: 0.7377
# Epoch 117/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5413 - accuracy: 0.7388
# Epoch 118/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5413 - accuracy: 0.7379
# Epoch 119/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5415 - accuracy: 0.7378
# Epoch 120/200
# 320/804 [==========>...................] - ETA: 1s - loss: 0.5427 - accuracy: 0.7333
# Epoch 120: saving model to optimized_checkpoints/weights.120.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5411 - accuracy: 0.7382
# Epoch 121/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7388
# Epoch 122/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7386
# Epoch 123/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7383
# Epoch 124/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7392
# Epoch 125/200
# 288/804 [=========>....................] - ETA: 1s - loss: 0.5376 - accuracy: 0.7456
# Epoch 125: saving model to optimized_checkpoints/weights.125.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5405 - accuracy: 0.7393
# Epoch 126/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5408 - accuracy: 0.7390
# Epoch 127/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5409 - accuracy: 0.7384
# Epoch 128/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5406 - accuracy: 0.7391
# Epoch 129/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5408 - accuracy: 0.7386
# Epoch 130/200
# 266/804 [========>.....................] - ETA: 1s - loss: 0.5411 - accuracy: 0.7331
# Epoch 130: saving model to optimized_checkpoints/weights.130.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7385
# Epoch 131/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5402 - accuracy: 0.7401
# Epoch 132/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7389
# Epoch 133/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5403 - accuracy: 0.7385
# Epoch 134/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5401 - accuracy: 0.7396
# Epoch 135/200
# 259/804 [========>.....................] - ETA: 1s - loss: 0.5415 - accuracy: 0.7368
# Epoch 135: saving model to optimized_checkpoints/weights.135.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5404 - accuracy: 0.7388
# Epoch 136/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5404 - accuracy: 0.7394
# Epoch 137/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5403 - accuracy: 0.7388
# Epoch 138/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5399 - accuracy: 0.7395
# Epoch 139/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5399 - accuracy: 0.7389
# Epoch 140/200
# 242/804 [========>.....................] - ETA: 1s - loss: 0.5432 - accuracy: 0.7366
# Epoch 140: saving model to optimized_checkpoints/weights.140.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5400 - accuracy: 0.7383
# Epoch 141/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5401 - accuracy: 0.7384
# Epoch 142/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5401 - accuracy: 0.7399
# Epoch 143/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5400 - accuracy: 0.7392
# Epoch 144/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7402
# Epoch 145/200
# 205/804 [======>.......................] - ETA: 1s - loss: 0.5483 - accuracy: 0.7314
# Epoch 145: saving model to optimized_checkpoints/weights.145.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5397 - accuracy: 0.7394
# Epoch 146/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5399 - accuracy: 0.7392
# Epoch 147/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7395
# Epoch 148/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5395 - accuracy: 0.7393
# Epoch 149/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5394 - accuracy: 0.7400
# Epoch 150/200
# 196/804 [======>.......................] - ETA: 1s - loss: 0.5329 - accuracy: 0.7425
# Epoch 150: saving model to optimized_checkpoints/weights.150.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5395 - accuracy: 0.7390
# Epoch 151/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5393 - accuracy: 0.7401
# Epoch 152/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5393 - accuracy: 0.7395
# Epoch 153/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5393 - accuracy: 0.7395
# Epoch 154/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7399
# Epoch 155/200
# 168/804 [=====>........................] - ETA: 1s - loss: 0.5358 - accuracy: 0.7435
# Epoch 155: saving model to optimized_checkpoints/weights.155.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5392 - accuracy: 0.7401
# Epoch 156/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5393 - accuracy: 0.7404
# Epoch 157/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5392 - accuracy: 0.7400
# Epoch 158/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5389 - accuracy: 0.7395
# Epoch 159/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5389 - accuracy: 0.7405
# Epoch 160/200
# 162/804 [=====>........................] - ETA: 1s - loss: 0.5377 - accuracy: 0.7404
# Epoch 160: saving model to optimized_checkpoints/weights.160.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5389 - accuracy: 0.7401
# Epoch 161/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5388 - accuracy: 0.7394
# Epoch 162/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5390 - accuracy: 0.7404
# Epoch 163/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5389 - accuracy: 0.7404
# Epoch 164/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5388 - accuracy: 0.7401
# Epoch 165/200
# 132/804 [===>..........................] - ETA: 2s - loss: 0.5354 - accuracy: 0.7410
# Epoch 165: saving model to optimized_checkpoints/weights.165.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5385 - accuracy: 0.7407
# Epoch 166/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5387 - accuracy: 0.7407
# Epoch 167/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5387 - accuracy: 0.7398
# Epoch 168/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5390 - accuracy: 0.7397
# Epoch 169/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5386 - accuracy: 0.7401
# Epoch 170/200
# 119/804 [===>..........................] - ETA: 1s - loss: 0.5420 - accuracy: 0.7398
# Epoch 170: saving model to optimized_checkpoints/weights.170.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5387 - accuracy: 0.7394
# Epoch 171/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5386 - accuracy: 0.7394
# Epoch 172/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.7398
# Epoch 173/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5385 - accuracy: 0.7397
# Epoch 174/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.7402
# Epoch 175/200
#  97/804 [==>...........................] - ETA: 1s - loss: 0.5576 - accuracy: 0.7268
# Epoch 175: saving model to optimized_checkpoints/weights.175.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5384 - accuracy: 0.7400
# Epoch 176/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5379 - accuracy: 0.7407
# Epoch 177/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5381 - accuracy: 0.7404
# Epoch 178/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5382 - accuracy: 0.7403
# Epoch 179/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.7407
# Epoch 180/200
#  78/804 [=>............................] - ETA: 1s - loss: 0.5253 - accuracy: 0.7452
# Epoch 180: saving model to optimized_checkpoints/weights.180.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.7407
# Epoch 181/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5380 - accuracy: 0.7402
# Epoch 182/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.7406
# Epoch 183/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5379 - accuracy: 0.7406
# Epoch 184/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5378 - accuracy: 0.7405
# Epoch 185/200
#  62/804 [=>............................] - ETA: 4s - loss: 0.5407 - accuracy: 0.7344
# Epoch 185: saving model to optimized_checkpoints/weights.185.hdf5
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5381 - accuracy: 0.7404
# Epoch 186/200
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5382 - accuracy: 0.7401
# Epoch 187/200
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5380 - accuracy: 0.7404
# Epoch 188/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5379 - accuracy: 0.7409
# Epoch 189/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5379 - accuracy: 0.7406
# Epoch 190/200
#  42/804 [>.............................] - ETA: 3s - loss: 0.5259 - accuracy: 0.7500
# Epoch 190: saving model to optimized_checkpoints/weights.190.hdf5
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5379 - accuracy: 0.7402
# Epoch 191/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5381 - accuracy: 0.7399
# Epoch 192/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5380 - accuracy: 0.7409
# Epoch 193/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5377 - accuracy: 0.7408
# Epoch 194/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5377 - accuracy: 0.7412
# Epoch 195/200
#  17/804 [..............................] - ETA: 2s - loss: 0.5027 - accuracy: 0.7647
# Epoch 195: saving model to optimized_checkpoints/weights.195.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5375 - accuracy: 0.7407
# Epoch 196/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5374 - accuracy: 0.7407
# Epoch 197/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5376 - accuracy: 0.7406
# Epoch 198/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5379 - accuracy: 0.7402
# Epoch 199/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5376 - accuracy: 0.7402
# Epoch 200/200
#   1/804 [..............................] - ETA: 8s - loss: 0.6339 - accuracy: 0.6875
# Epoch 200: saving model to optimized_checkpoints/weights.200.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5372 - accuracy: 0.7406

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# 268/268 - 1s - loss: 1.9105 - accuracy: 0.6568 - 787ms/epoch - 3ms/step
# Loss: 1.910455584526062, Accuracy: 0.6567929983139038

# %%
# Export the model to HDF5 file
nn.save('AlphabetSoupCharity_Optimization.h5')

# %%
from google.colab import files
files.download("AlphabetSoupCharity_Optimization.h5")
